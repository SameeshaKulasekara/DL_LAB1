# %% [markdown]
# <a href="https://colab.research.google.com/github/SameeshaKulasekara/DL_LAB1/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arraysize = (4,4)

sample1 = np.random.exponential(1, arraysize)

# %%
sample1
# Out:
# array([[0.45489391, 0.48180932, 0.18989969, 0.93163129],
#        [0.47612268, 1.19162656, 0.55127629, 0.35248319],
#        [0.50603725, 4.5206628 , 0.62145996, 0.6373012 ],
#        [0.55147799, 1.68262331, 0.04112211, 0.47882493]])

# %%
arraysize = (1000,1)

sample2 = np.random.exponential(1, arraysize)

print(sample2)
# Out:
# [[1.36479087e+00]
#  [8.94457449e-01]
#  [7.80425026e-02]
#  [6.60397476e-01]
#  [2.16459932e-01]
#  [8.68757631e-01]
#  [8.23055579e-01]
#  [2.01998471e+00]
#  [5.63156832e-02]
#  [2.25881448e-01]
#  [4.28090558e-02]
#  [1.98276535e+00]
#  [8.81317308e-01]
#  [3.71716579e-01]
#  [1.69709731e+00]
#  [8.02452966e-02]
#  [3.34076476e-02]
#  [6.34519388e-01]
#  [3.36464759e-01]
#  [1.11592183e+00]
#  [2.13321453e-01]
#  [4.88069559e+00]
#  [2.09282853e-01]
#  [1.87276593e-01]
#  [5.36782747e-01]
#  [1.67640175e-01]
#  [1.45031477e+00]
#  [4.86874530e-02]
#  [1.02079307e+00]
#  [1.27934110e+00]
#  [1.69947437e+00]
#  [1.14275228e+00]
#  [3.52357785e-01]
#  [1.32941174e-01]
#  [4.64349604e-01]
#  [2.92546735e+00]
#  [1.61595631e+00]
#  [4.61577651e-01]
#  [1.29595487e+00]
#  [7.15582245e-01]
#  [4.41056052e-01]
#  [1.22209872e+00]
#  [8.42205036e-01]
#  [1.24397669e+00]
#  [5.47247881e-01]
#  [6.16901150e-01]
#  [4.15136105e-01]
#  [2.54968449e-01]
#  [3.63451434e-01]
#  [1.21227522e-01]
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(np.random.rand(100000), density=True, bins=200, histtype="step", color="blue", label="rand")
plt.axis([-2.5, 2.5, 0, 1.1])
plt.legend(loc = "upper left")
plt.title("Random distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
P = np.sqrt(X**2 + Y**2)
Z = np.sin(P)

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.coolwarm, linewidth=0.1)
plt.show()
